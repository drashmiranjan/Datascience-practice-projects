# %% [markdown]
# ecommerce_orders_dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Lenovo/OneDrive/Desktop/ds/Dataset/ecommerce_orders_dataset.csv")

# %%
# find Top 10 Datas from the csv file
df.head(10)
# Out:
#    Order_ID Customer_ID  Order_Date  Year  Month  Day Day_Of_Week  Quarter  \
# 0    615717  CUST007322  2023-01-01  2023      1    1      Sunday        1
# 1    626919  CUST004717  2023-01-01  2023      1    1      Sunday        1
# 2    615781  CUST004415  2023-01-01  2023      1    1      Sunday        1
# 3    621747  CUST004114  2023-01-01  2023      1    1      Sunday        1
# 4    625881  CUST000145  2023-01-01  2023      1    1      Sunday        1
# 5    613497  CUST000940  2023-01-01  2023      1    1      Sunday        1
# 6    600746  CUST004139  2023-01-01  2023      1    1      Sunday        1
# 7    604774  CUST000543  2023-01-01  2023      1    1      Sunday        1
# 8    600323  CUST003309  2023-01-01  2023      1    1      Sunday        1
# 9    608449  CUST006419  2023-01-01  2023      1    1      Sunday        1
#
#    Customer_Age Customer_Gender  ... Delivery_Days Order_Status Returned  \
# ...

# %%
df.shape
# Out:
# (30000, 41)

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Order_Date', 'Year', 'Month', 'Day',
#        'Day_Of_Week', 'Quarter', 'Customer_Age', 'Customer_Gender', 'Country',
#        'City', 'Customer_Segment', 'Product_ID', 'Product_Category',
#        'Product_Subcategory', 'Brand', 'Unit_Price', 'Quantity',
#        'Discount_Percent', 'Discount_Amount', 'Coupon_Used', 'Shipping_Cost',
#        'Tax_Amount', 'Order_Amount', 'Payment_Method', 'Device_Type',
#        'Traffic_Source', 'Membership_Status', 'Shipping_Method',
#        'Warehouse_Region', 'Delivery_Days', 'Order_Status', 'Returned',
#        'Review_Rating', 'Customer_Lifetime_Value', 'Profit_Margin_Percent',
#        'Profit_Amount', 'Season', 'Holiday_Season', 'High_Value_Order'],
#       dtype='object')

# %%
df["Customer_Gender"].head(20)
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# 5     Female
# 6     Female
# 7     Female
# 8     Female
# 9      Other
# 10    Female
# 11    Female
# 12    Female
# 13      Male
# 14      Male
# 15    Female
# 16      Male
# 17    Female
# 18      Male
# 19      Male
# Name: Customer_Gender, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order_ID                 30000 non-null  int64
#  1   Customer_ID              30000 non-null  object
#  2   Order_Date               30000 non-null  object
#  3   Year                     30000 non-null  int64
#  4   Month                    30000 non-null  int64
#  5   Day                      30000 non-null  int64
#  6   Day_Of_Week              30000 non-null  object
#  7   Quarter                  30000 non-null  int64
#  8   Customer_Age             30000 non-null  int64
#  9   Customer_Gender          30000 non-null  object
#  10  Country                  30000 non-null  object
#  11  City                     30000 non-null  object
#  12  Customer_Segment         30000 non-null  object
#  13  Product_ID               30000 non-null  object
# ...

# %%
df["Customer_Gender"].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
df["Customer_Segment"].head(10)
# Out:
# 0        Loyal
# 1    Returning
# 2    Returning
# 3    Returning
# 4      Premium
# 5          New
# 6    Returning
# 7      Premium
# 8    Returning
# 9    Returning
# Name: Customer_Segment, dtype: object

# %%
df["Customer_Segment"].unique()
# Out:
# array(['Loyal', 'Returning', 'Premium', 'New'], dtype=object)

# %%
df["Country"].describe()
# Out:
# count      30000
# unique        10
# top       Canada
# freq        3099
# Name: Country, dtype: object

# %% [markdown]
# Task1 - Which Month sales is more in India

# %%
df.loc[df['Customer_ID'] == "CUST004415", 'Country']
# Out:
# 2               India
# 131           Germany
# 406               UAE
# 20417             UAE
# 29034    Saudi Arabia
# Name: Country, dtype: object

# %%
df[df["Country"] == "India"].head(10)
# Out:
#     Order_ID Customer_ID  Order_Date  Year  Month  Day Day_Of_Week  Quarter  \
# 2     615781  CUST004415  2023-01-01  2023      1    1      Sunday        1
# 4     625881  CUST000145  2023-01-01  2023      1    1      Sunday        1
# 11    628771  CUST002640  2023-01-01  2023      1    1      Sunday        1
# 32    602516  CUST004129  2023-01-02  2023      1    2      Monday        1
# 36    606625  CUST006843  2023-01-02  2023      1    2      Monday        1
# 37    613453  CUST004116  2023-01-02  2023      1    2      Monday        1
# 43    621506  CUST002437  2023-01-02  2023      1    2      Monday        1
# 57    609669  CUST007436  2023-01-03  2023      1    3     Tuesday        1
# 71    611974  CUST007663  2023-01-04  2023      1    4   Wednesday        1
# 97    619796  CUST005785  2023-01-05  2023      1    5    Thursday        1
#
#     Customer_Age Customer_Gender  ... Delivery_Days Order_Status Returned  \
# ...

# %%
india_df = df[df["Country"] == "India"]

# %%
india_df
# Out:
#        Order_ID Customer_ID  Order_Date  Year  Month  Day Day_Of_Week  \
# 2        615781  CUST004415  2023-01-01  2023      1    1      Sunday
# 4        625881  CUST000145  2023-01-01  2023      1    1      Sunday
# 11       628771  CUST002640  2023-01-01  2023      1    1      Sunday
# 32       602516  CUST004129  2023-01-02  2023      1    2      Monday
# 36       606625  CUST006843  2023-01-02  2023      1    2      Monday
# ...         ...         ...         ...   ...    ...  ...         ...
# 29977    603865  CUST004741  2026-12-30  2026     12   30   Wednesday
# 29981    619915  CUST000579  2026-12-31  2026     12   31    Thursday
# 29986    628484  CUST000076  2026-12-31  2026     12   31    Thursday
# 29987    618435  CUST007265  2026-12-31  2026     12   31    Thursday
# 29991    608441  CUST004583  2026-12-31  2026     12   31    Thursday
#
#        Quarter  Customer_Age Customer_Gender  ... Delivery_Days Order_Status  \
# ...

# %%
india_df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Order_Date', 'Year', 'Month', 'Day',
#        'Day_Of_Week', 'Quarter', 'Customer_Age', 'Customer_Gender', 'Country',
#        'City', 'Customer_Segment', 'Product_ID', 'Product_Category',
#        'Product_Subcategory', 'Brand', 'Unit_Price', 'Quantity',
#        'Discount_Percent', 'Discount_Amount', 'Coupon_Used', 'Shipping_Cost',
#        'Tax_Amount', 'Order_Amount', 'Payment_Method', 'Device_Type',
#        'Traffic_Source', 'Membership_Status', 'Shipping_Method',
#        'Warehouse_Region', 'Delivery_Days', 'Order_Status', 'Returned',
#        'Review_Rating', 'Customer_Lifetime_Value', 'Profit_Margin_Percent',
#        'Profit_Amount', 'Season', 'Holiday_Season', 'High_Value_Order'],
#       dtype='object')

# %%
india_monthly_sales_df = india_df.groupby("Month")["Order_Amount"].sum()

# %%
india_monthly_sales_df
# Out:
# Month
# 1      89317.68
# 2      88366.32
# 3     108274.56
# 4      83844.77
# 5      74509.89
# 6      95587.38
# 7     108526.85
# 8     102878.96
# 9     100061.57
# 10    100801.81
# 11     92200.71
# 12    100940.83
# Name: Order_Amount, dtype: float64

# %%
india_monthly_sales_df.sort_values(ascending=False)
# Out:
# Month
# 7     108526.85
# 3     108274.56
# 8     102878.96
# 12    100940.83
# 10    100801.81
# 9     100061.57
# 6      95587.38
# 11     92200.71
# 1      89317.68
# 2      88366.32
# 4      83844.77
# 5      74509.89
# Name: Order_Amount, dtype: float64

# %%
india_monthly_sales_df.idxmax()
# Out:
# np.int64(7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order_ID                 30000 non-null  int64
#  1   Customer_ID              30000 non-null  object
#  2   Order_Date               30000 non-null  object
#  3   Year                     30000 non-null  int64
#  4   Month                    30000 non-null  int64
#  5   Day                      30000 non-null  int64
#  6   Day_Of_Week              30000 non-null  object
#  7   Quarter                  30000 non-null  int64
#  8   Customer_Age             30000 non-null  int64
#  9   Customer_Gender          30000 non-null  object
#  10  Country                  30000 non-null  object
#  11  City                     30000 non-null  object
#  12  Customer_Segment         30000 non-null  object
#  13  Product_ID               30000 non-null  object
# ...

# %% [markdown]
# Task 2 - Which Customer Segment generates the highest revenue?

# %%
df["Customer_Segment"].unique()
# Out:
# array(['Loyal', 'Returning', 'Premium', 'New'], dtype=object)

# %%
Highest_revenue = df.groupby("Customer_Segment")["Order_Amount"].sum()

# %%
Highest_revenue
# Out:
# Customer_Segment
# Loyal        2659608.61
# New          2982575.91
# Premium      1145145.28
# Returning    4582714.19
# Name: Order_Amount, dtype: float64

# %%
Highest_revenue.sort_values(ascending=False)
# Out:
# Customer_Segment
# Returning    4582714.19
# New          2982575.91
# Loyal        2659608.61
# Premium      1145145.28
# Name: Order_Amount, dtype: float64

# %%
df["Customer_Segment"].value_counts()
# Out:
# Customer_Segment
# Returning    11987
# New           7794
# Loyal         7214
# Premium       3005
# Name: count, dtype: int64

# %% [markdown]
# lets check which customer_segement get high discount may be this will help that returing customer have high revenue

# %%
df.groupby("Customer_Segment")["Discount_Percent"].mean().sort_values(ascending=False)
# Out:
# Customer_Segment
# New          12.705286
# Loyal        12.660105
# Returning    12.575707
# Premium      12.465890
# Name: Discount_Percent, dtype: float64

# %% [markdown]
# Lets check in which customer segement people spend more

# %%
df.groupby("Customer_Segment")["Order_Amount"].mean().sort_values(ascending=False)
# Out:
# Customer_Segment
# New          382.675893
# Returning    382.307015
# Premium      381.079960
# Loyal        368.673220
# Name: Order_Amount, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order_ID                 30000 non-null  int64
#  1   Customer_ID              30000 non-null  object
#  2   Order_Date               30000 non-null  object
#  3   Year                     30000 non-null  int64
#  4   Month                    30000 non-null  int64
#  5   Day                      30000 non-null  int64
#  6   Day_Of_Week              30000 non-null  object
#  7   Quarter                  30000 non-null  int64
#  8   Customer_Age             30000 non-null  int64
#  9   Customer_Gender          30000 non-null  object
#  10  Country                  30000 non-null  object
#  11  City                     30000 non-null  object
#  12  Customer_Segment         30000 non-null  object
#  13  Product_ID               30000 non-null  object
# ...

# %%
df.groupby("Customer_Segment")["Profit_Amount"].sum().sort_values(ascending=False)
# Out:
# Customer_Segment
# Returning    888003.26
# New          579346.30
# Loyal        526075.50
# Premium      222491.21
# Name: Profit_Amount, dtype: float64

# %%
pd.crosstab(
    df["Customer_Segment"],
    df["Returned"],
)
# Out:
# Returned             No   Yes
# Customer_Segment
# Loyal              6491   723
# New                6895   899
# Premium            2725   280
# Returning         10856  1131

# %%
pd.crosstab(
    df["Customer_Segment"],
    df["Returned"],
    normalize="index"
)*100
# Out:
# Returned                 No        Yes
# Customer_Segment
# Loyal             89.977821  10.022179
# New               88.465486  11.534514
# Premium           90.682196   9.317804
# Returning         90.564779   9.435221

# %%
df[["Customer_Segment", "Quantity"]].head(10)
# Out:
#   Customer_Segment  Quantity
# 0            Loyal         3
# 1        Returning         1
# 2        Returning         3
# 3        Returning         3
# 4          Premium         1
# 5              New         3
# 6        Returning         3
# 7          Premium         1
# 8        Returning         1
# 9        Returning         5

# %%
df.groupby("Customer_Segment")["Quantity"].mean().sort_values(ascending=False)
# Out:
# Customer_Segment
# Premium      3.106822
# New          3.084937
# Returning    3.078752
# Loyal        3.068339
# Name: Quantity, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order_ID                 30000 non-null  int64
#  1   Customer_ID              30000 non-null  object
#  2   Order_Date               30000 non-null  object
#  3   Year                     30000 non-null  int64
#  4   Month                    30000 non-null  int64
#  5   Day                      30000 non-null  int64
#  6   Day_Of_Week              30000 non-null  object
#  7   Quarter                  30000 non-null  int64
#  8   Customer_Age             30000 non-null  int64
#  9   Customer_Gender          30000 non-null  object
#  10  Country                  30000 non-null  object
#  11  City                     30000 non-null  object
#  12  Customer_Segment         30000 non-null  object
#  13  Product_ID               30000 non-null  object
# ...
