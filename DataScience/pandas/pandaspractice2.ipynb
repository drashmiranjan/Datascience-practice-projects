# %%
import pandas as pd

# %%
df = pd.read_csv("D:/DataScience/Datascience-practice-projects/DataScience/Dataset/ecommerce_orders_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order_ID                 30000 non-null  int64
#  1   Customer_ID              30000 non-null  str
#  2   Order_Date               30000 non-null  str
#  3   Year                     30000 non-null  int64
#  4   Month                    30000 non-null  int64
#  5   Day                      30000 non-null  int64
#  6   Day_Of_Week              30000 non-null  str
#  7   Quarter                  30000 non-null  int64
#  8   Customer_Age             30000 non-null  int64
#  9   Customer_Gender          30000 non-null  str
#  10  Country                  30000 non-null  str
#  11  City                     30000 non-null  str
#  12  Customer_Segment         30000 non-null  str
#  13  Product_ID               30000 non-null  str
# ...

# %% [markdown]
# # How many orders are there in total

# %%
df.shape
# Out:
# (30000, 41)

# %% [markdown]
# # How many unique customers purchased?

# %%
df["Customer_ID"].unique()
# Out:
# <StringArray>
# ['CUST007322', 'CUST004717', 'CUST004415', 'CUST004114', 'CUST000145',
#  'CUST000940', 'CUST004139', 'CUST000543', 'CUST003309', 'CUST006419',
#  ...
#  'CUST005440', 'CUST000994', 'CUST008793', 'CUST004066', 'CUST008408',
#  'CUST004854', 'CUST003307', 'CUST000398', 'CUST008677', 'CUST007265']
# Length: 8683, dtype: str

# %% [markdown]
# # Which customer segment places the most orders?

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Order_Date', 'Year', 'Month', 'Day',
#        'Day_Of_Week', 'Quarter', 'Customer_Age', 'Customer_Gender', 'Country',
#        'City', 'Customer_Segment', 'Product_ID', 'Product_Category',
#        'Product_Subcategory', 'Brand', 'Unit_Price', 'Quantity',
#        'Discount_Percent', 'Discount_Amount', 'Coupon_Used', 'Shipping_Cost',
#        'Tax_Amount', 'Order_Amount', 'Payment_Method', 'Device_Type',
#        'Traffic_Source', 'Membership_Status', 'Shipping_Method',
#        'Warehouse_Region', 'Delivery_Days', 'Order_Status', 'Returned',
#        'Review_Rating', 'Customer_Lifetime_Value', 'Profit_Margin_Percent',
#        'Profit_Amount', 'Season', 'Holiday_Season', 'High_Value_Order'],
#       dtype='str')

# %%
df["Customer_Segment"].head(10)
# Out:
# 0        Loyal
# 1    Returning
# 2    Returning
# 3    Returning
# 4      Premium
# 5          New
# 6    Returning
# 7      Premium
# 8    Returning
# 9    Returning
# Name: Customer_Segment, dtype: str

# %%
df["Customer_Segment"].value_counts().head(1)
# Out:
# Customer_Segment
# Returning    11987
# Name: count, dtype: int64

# %% [markdown]
# # Which country generates the highest revenue?

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Order_Date', 'Year', 'Month', 'Day',
#        'Day_Of_Week', 'Quarter', 'Customer_Age', 'Customer_Gender', 'Country',
#        'City', 'Customer_Segment', 'Product_ID', 'Product_Category',
#        'Product_Subcategory', 'Brand', 'Unit_Price', 'Quantity',
#        'Discount_Percent', 'Discount_Amount', 'Coupon_Used', 'Shipping_Cost',
#        'Tax_Amount', 'Order_Amount', 'Payment_Method', 'Device_Type',
#        'Traffic_Source', 'Membership_Status', 'Shipping_Method',
#        'Warehouse_Region', 'Delivery_Days', 'Order_Status', 'Returned',
#        'Review_Rating', 'Customer_Lifetime_Value', 'Profit_Margin_Percent',
#        'Profit_Amount', 'Season', 'Holiday_Season', 'High_Value_Order'],
#       dtype='str')

# %%
df["Country"].value_counts().head(1)
# Out:
# Country
# Canada    3099
# Name: count, dtype: int64

# %% [markdown]
# # Find top 10 customers by revenue.

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Order_Date', 'Year', 'Month', 'Day',
#        'Day_Of_Week', 'Quarter', 'Customer_Age', 'Customer_Gender', 'Country',
#        'City', 'Customer_Segment', 'Product_ID', 'Product_Category',
#        'Product_Subcategory', 'Brand', 'Unit_Price', 'Quantity',
#        'Discount_Percent', 'Discount_Amount', 'Coupon_Used', 'Shipping_Cost',
#        'Tax_Amount', 'Order_Amount', 'Payment_Method', 'Device_Type',
#        'Traffic_Source', 'Membership_Status', 'Shipping_Method',
#        'Warehouse_Region', 'Delivery_Days', 'Order_Status', 'Returned',
#        'Review_Rating', 'Customer_Lifetime_Value', 'Profit_Margin_Percent',
#        'Profit_Amount', 'Season', 'Holiday_Season', 'High_Value_Order'],
#       dtype='str')

# %%
df.groupby("Customer_ID")["Order_Amount"].sum().sort_values(ascending=False).head(10)
# Out:
# Customer_ID
# CUST000459    10712.12
# CUST006906    10179.74
# CUST000025     9308.43
# CUST000381     9035.20
# CUST005303     8789.97
# CUST000677     8682.57
# CUST008949     8681.58
# CUST001750     8615.22
# CUST003335     8558.97
# CUST005767     8272.02
# Name: Order_Amount, dtype: float64

# %% [markdown]
# # Average order value per segment

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Order_Date', 'Year', 'Month', 'Day',
#        'Day_Of_Week', 'Quarter', 'Customer_Age', 'Customer_Gender', 'Country',
#        'City', 'Customer_Segment', 'Product_ID', 'Product_Category',
#        'Product_Subcategory', 'Brand', 'Unit_Price', 'Quantity',
#        'Discount_Percent', 'Discount_Amount', 'Coupon_Used', 'Shipping_Cost',
#        'Tax_Amount', 'Order_Amount', 'Payment_Method', 'Device_Type',
#        'Traffic_Source', 'Membership_Status', 'Shipping_Method',
#        'Warehouse_Region', 'Delivery_Days', 'Order_Status', 'Returned',
#        'Review_Rating', 'Customer_Lifetime_Value', 'Profit_Margin_Percent',
#        'Profit_Amount', 'Season', 'Holiday_Season', 'High_Value_Order'],
#       dtype='str')

# %%
df.groupby("Customer_Segment")["Order_Amount"].mean()
# Out:
# Customer_Segment
# Loyal        368.673220
# New          382.675893
# Premium      381.079960
# Returning    382.307015
# Name: Order_Amount, dtype: float64

# %% [markdown]
# # Which segment returns products most frequently?

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Order_Date', 'Year', 'Month', 'Day',
#        'Day_Of_Week', 'Quarter', 'Customer_Age', 'Customer_Gender', 'Country',
#        'City', 'Customer_Segment', 'Product_ID', 'Product_Category',
#        'Product_Subcategory', 'Brand', 'Unit_Price', 'Quantity',
#        'Discount_Percent', 'Discount_Amount', 'Coupon_Used', 'Shipping_Cost',
#        'Tax_Amount', 'Order_Amount', 'Payment_Method', 'Device_Type',
#        'Traffic_Source', 'Membership_Status', 'Shipping_Method',
#        'Warehouse_Region', 'Delivery_Days', 'Order_Status', 'Returned',
#        'Review_Rating', 'Customer_Lifetime_Value', 'Profit_Margin_Percent',
#        'Profit_Amount', 'Season', 'Holiday_Season', 'High_Value_Order'],
#       dtype='str')

# %%
df.groupby("Customer_Segment")["Returned"].size
# Out:
# <bound method GroupBy.size of <pandas.api.typing.SeriesGroupBy object at 0x00000161CF3AAE10>>

# %%
df[df["Returned"] == "Yes"]["Customer_Segment"].value_counts()
# Out:
# Customer_Segment
# Returning    1131
# New           899
# Loyal         723
# Premium       280
# Name: count, dtype: int64

# %% [markdown]
# # Top 10 profitable products

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Order_Date', 'Year', 'Month', 'Day',
#        'Day_Of_Week', 'Quarter', 'Customer_Age', 'Customer_Gender', 'Country',
#        'City', 'Customer_Segment', 'Product_ID', 'Product_Category',
#        'Product_Subcategory', 'Brand', 'Unit_Price', 'Quantity',
#        'Discount_Percent', 'Discount_Amount', 'Coupon_Used', 'Shipping_Cost',
#        'Tax_Amount', 'Order_Amount', 'Payment_Method', 'Device_Type',
#        'Traffic_Source', 'Membership_Status', 'Shipping_Method',
#        'Warehouse_Region', 'Delivery_Days', 'Order_Status', 'Returned',
#        'Review_Rating', 'Customer_Lifetime_Value', 'Profit_Margin_Percent',
#        'Profit_Amount', 'Season', 'Holiday_Season', 'High_Value_Order'],
#       dtype='str')

# %%
d
# Out:
# 0    15.75
# 1     3.32
# 2    45.67
# 3    75.25
# 4    26.06
# Name: Profit_Amount, dtype: float64

# %%
df.groupby("Product_Category")["Profit_Amount"].max().sort_values(ascending=False)
# Out:
# Product_Category
# Electronics       2480.54
# Home & Kitchen     758.78
# Sports             516.54
# Beauty             404.69
# Fashion            397.41
# Toys               223.00
# Books              128.80
# Groceries           89.89
# Name: Profit_Amount, dtype: float64

# %% [markdown]
# # Monthly sales trend.

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Order_Date', 'Year', 'Month', 'Day',
#        'Day_Of_Week', 'Quarter', 'Customer_Age', 'Customer_Gender', 'Country',
#        'City', 'Customer_Segment', 'Product_ID', 'Product_Category',
#        'Product_Subcategory', 'Brand', 'Unit_Price', 'Quantity',
#        'Discount_Percent', 'Discount_Amount', 'Coupon_Used', 'Shipping_Cost',
#        'Tax_Amount', 'Order_Amount', 'Payment_Method', 'Device_Type',
#        'Traffic_Source', 'Membership_Status', 'Shipping_Method',
#        'Warehouse_Region', 'Delivery_Days', 'Order_Status', 'Returned',
#        'Review_Rating', 'Customer_Lifetime_Value', 'Profit_Margin_Percent',
#        'Profit_Amount', 'Season', 'Holiday_Season', 'High_Value_Order'],
#       dtype='str')

# %%
df.groupby("Month")["Order_Amount"].sum().sort_values(ascending=False)
# Out:
# Month
# 8     1071268.49
# 3     1010299.50
# 12     993858.06
# 1      936076.62
# 11     930805.06
# 7      930656.68
# 4      924831.93
# 2      921195.64
# 9      919010.17
# 6      918539.05
# 5      913148.58
# 10     900354.21
# Name: Order_Amount, dtype: float64

# %% [markdown]
# # Which day of week gets maximum sales?

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Order_Date', 'Year', 'Month', 'Day',
#        'Day_Of_Week', 'Quarter', 'Customer_Age', 'Customer_Gender', 'Country',
#        'City', 'Customer_Segment', 'Product_ID', 'Product_Category',
#        'Product_Subcategory', 'Brand', 'Unit_Price', 'Quantity',
#        'Discount_Percent', 'Discount_Amount', 'Coupon_Used', 'Shipping_Cost',
#        'Tax_Amount', 'Order_Amount', 'Payment_Method', 'Device_Type',
#        'Traffic_Source', 'Membership_Status', 'Shipping_Method',
#        'Warehouse_Region', 'Delivery_Days', 'Order_Status', 'Returned',
#        'Review_Rating', 'Customer_Lifetime_Value', 'Profit_Margin_Percent',
#        'Profit_Amount', 'Season', 'Holiday_Season', 'High_Value_Order'],
#       dtype='str')

# %%
df[df["Returned"] == "No"]["Day_Of_Week"].value_counts().head(1)
# Out:
# Day_Of_Week
# Monday    3901
# Name: count, dtype: int64

# %%
df.groupby("Day_Of_Week")["Order_Amount"].max().sort_values(ascending=False).head(1)
# Out:
# Day_Of_Week
# Monday    10314.27
# Name: Order_Amount, dtype: float64
